# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import os

# %% [markdown]
# # Define path variables

# %%
data_root_dpath = os.path.join("..", "data", "OPP-115")

processed_data_dpath = os.path.join(data_root_dpath, "processed_data")

catsplit_annotations_115_parsed_dpath = os.path.join(processed_data_dpath, "catsplit_annotations_115_parsed")

# %% [markdown]
# # First Party Collection/Use

# %%
df = pd.read_csv(os.path.join(catsplit_annotations_115_parsed_dpath, "First_Party_Collection-Use.csv"))
df
# Out:
#       annotation_ID  annotator_ID  segment_ID                    category  \
# 0             13161           121           1  First Party Collection/Use
# 1             13162           121           1  First Party Collection/Use
# 2             13163           121           1  First Party Collection/Use
# 3             13164           121           1  First Party Collection/Use
# 4             13165           121           1  First Party Collection/Use
# ...             ...           ...         ...                         ...
# 8930           3296            82          13  First Party Collection/Use
# 8931           3297            82          13  First Party Collection/Use
# 8932           3298            82          13  First Party Collection/Use
# 8933           3299            82          13  First Party Collection/Use
# 8934           3250            88          26  First Party Collection/Use
#
#       policy_ID                                       segment_text  \
# 0           746   Information We Collect     Personally-Identif...
# 1           746   Information We Collect     Personally-Identif...
# 2           746   Information We Collect     Personally-Identif...
# 3           746   Information We Collect     Personally-Identif...
# 4           746   Information We Collect     Personally-Identif...
# ...         ...                                                ...
# 8930       1545  We use "web beacons" and "web logs" to allow o...
# 8931       1545  We use "web beacons" and "web logs" to allow o...
# 8932       1545  We use "web beacons" and "web logs" to allow o...
# 8933       1545  We use "web beacons" and "web logs" to allow o...
# 8934       1545  We do not participate in tracking networks and...
#
#      Collection Mode Choice Scope            Action First-Party  \
# 0       not-selected   Collection            Collect on website
# 1       not-selected   Collection            Collect on website
# 2       not-selected   Collection            Collect on website
# 3       not-selected   Collection            Collect on website
# 4       not-selected   Collection            Collect on website
# ...              ...          ...                           ...
# 8930        Implicit  Unspecified                   Unspecified
# 8931        Implicit  Unspecified                   Unspecified
# 8932        Implicit  Unspecified                   Unspecified
# 8933        Implicit  Unspecified                   Unspecified
# 8934        Implicit  Unspecified  Track user on other websites
#
#          Personal Information Type  Choice Type Identifiability Does/Does Not  \
# 0     Generic personal information       Opt-in     Unspecified          Does
# 1     Generic personal information       Opt-in     Unspecified          Does
# 2     Generic personal information       Opt-in     Unspecified          Does
# 3                          Contact       Opt-in     Unspecified          Does
# 4                      Demographic       Opt-in     Unspecified          Does
# ...                            ...          ...             ...           ...
# 8930     IP address and device IDs  Unspecified     Unspecified          Does
# 8931                      Location  Unspecified     Unspecified          Does
# 8932          Computer information  Unspecified     Unspecified          Does
# 8933        User online activities  Unspecified     Unspecified          Does
# 8934                   Unspecified  Unspecified     Unspecified      Does Not
#
#         User Type                        Purpose
# 0     Unspecified     Additional service/feature
# 1     Unspecified  Personalization/Customization
# 2     Unspecified                      Marketing
# 3     Unspecified     Additional service/feature
# 4     Unspecified     Additional service/feature
# ...           ...                            ...
# 8930  Unspecified          Basic service/feature
# 8931  Unspecified          Basic service/feature
# 8932  Unspecified          Basic service/feature
# 8933  Unspecified          Basic service/feature
# 8934  Unspecified                          Other
#
# [8935 rows x 15 columns]

# %% [markdown]
# # Third Party Sharing/Collection

# %% [markdown]
# # User Choice/Control

# %% [markdown]
# # User Access/Edit & Deletion

# %% [markdown]
# # Data Retention

# %% [markdown]
# # Data Security

# %% [markdown]
# # Policy Change

# %% [markdown]
# # Do Not Track

# %% [markdown]
# # International & Specific Audiences
